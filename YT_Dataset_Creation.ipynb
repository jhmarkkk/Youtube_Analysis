# %%
import constants

API_KEY = constants.API_KEY

from googleapiclient.discovery import build

# %%
youtube = build('youtube', 'v3', developerKey=API_KEY) #this is a Service

# %% [markdown]
# # Video Id of Trending videos
# We will create an array trending_id containing the video Ids of trending videos.

# %%
request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        chart="mostPopular",
        regionCode="US",
        maxResults=50
    )

trending = request.execute()
print(trending)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': 's_WS_wv6MAIkATsUQaiz3841qxo', 'items': [{'kind': 'youtube#video', 'etag': 'urq7Igq3i5LgXtP0cgLwvdITm4M', 'id': 'YLt73w6criQ', 'snippet': {'publishedAt': '2023-03-18T20:00:01Z', 'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA', 'title': 'I Paid A Real Assassin To Try To Kill Me', 'description': 'File with TurboTax today to get your biggest refund possible 🤑\n http://bit.ly/MrBeastxTurboTax\n\nNew Merch - https://shopmrbeast.com/\n\nSUBSCRIBE OR I TAKE YOUR DOG\n╔═╦╗╔╦╗╔═╦═╦╦╦╦╗╔═╗\n║╚╣║║║╚╣╚╣╔╣╔╣║╚╣═╣ \n╠╗║╚╝║║╠╗║╚╣║║║║║═╣\n╚═╩══╩═╩═╩═╩╝╚╩═╩═╝\n\n----------------------------------------------------------------\nfollow all of these or i will kick you\n• Facebook - https://www.facebook.com/MrBeast6000/\n• Twitter - https://twitter.com/MrBeast\n•  Instagram - https://www.instagram.com/mrbeast\n•  Im Hiring! - https://www.mrbeastjobs.com/\n--------------------------------------------------------------------', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/YLt73w6criQ/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/YLt73w6criQ/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/YLt73w6criQ/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/YLt73w6criQ/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/YLt73w6criQ/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'MrBeast', 'categoryId': '24', 'liveBroadcastContent': 'none', 'localized': {'title': 'I Paid A Real Assassin To Try To Kill Me', 'description': 'File with TurboTax today to get your biggest refund possible 🤑\n http://bit.ly/MrBeastxTurboTax\n\nNew Merch - https://shopmrbeast.com/\n\nSUBSCRIBE OR I TAKE YOUR DOG\n╔═╦╗╔╦╗╔═╦═╦╦╦╦╗╔═╗\n║╚╣║║║╚╣╚╣╔╣╔╣║╚╣═╣ \n╠╗║╚╝║║╠╗║╚╣║║║║║═╣\n╚═╩══╩═╩═╩═╩╝╚╩═╩═╝\n\n----------------------------------------------------------------\nfollow all of these or i will kick you\n• Facebook - https://www.facebook.com/MrBeast6000/\n• Twitter - https://twitter.com/MrBeast\n•  Instagram - https://www.instagram.com/mrbeast\n•  Im Hiring! - https://www.mrbeastjobs.com/\n--------------------------------------------------------------------'}, 'defaultAudioLanguage': 'en'}, 'contentDetails': {'duration': 'PT12M17S', 'dimension': '2d', 'definition': 'hd', 'caption': 'true', 'licensedContent': True, 'contentRating': {}, 'projection': 'rectangular'}, 'statistics': {'viewCount': '36385671', 'likeCount': '2238282', 'favoriteCount': '0', 'commentCount': '78694'}}, {'kind': 'youtube#video', 'etag': 'CF2mK412y8RM1B45rJAvmjP060s', 'id': 'DOWDNBu9DkU', 'snippet': {'publishedAt': '2023-03-18T15:26:03Z', 'channelId': 'UCY1kMZp36IQSyNx_9h4mpCg', 'title': 'Amazing Invention- This Drone Will Change Everything', 'description': 'These folks engineering a much better way to deliver your basically anything. If you want to engineer your own creations with me every month, just head to https://www.crunchlabs.com where you can get 2 boxes FREE!\n\nAgain, this was not sponsored in anyway nor did they pay for any of my travel or accommodations but if you want to learn more about Zipline here is their website- https://www.flyzipline.com/\n\nPonder - https://soundcloud.com/prodbyponder\nLaura Shigihara -  @supershigi \nAndrew Applepie - https://soundcloud.com/andrewapplepie\nBlue Wednesday - https://soundcloud.com/bluewednesday', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DOWDNBu9DkU/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/DOWDNBu9DkU/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/DOWDNBu9DkU/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/DOWDNBu9DkU/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/DOWDNBu9DkU/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'Mark Rober', 'categor ...

# %%
trending_id = []

for video in trending["items"]:
    trending_id.append(video["id"])
    
trending_id = list(set(trending_id))
print(trending_id)
print(len(trending_id))
# Out:
# ['PZM6j8bKnks', 'tfy2yGuV6wk', 'peTZrb5q5ag', 'aAHsVfGC4_E', '6DWjiWEmxME', 'gvPCS-uaw6c', 'GMr5Id1IxBw', 'YLt73w6criQ', 'Ee4pNvB7IEs', 'S9rpZBloeBw', 'CSfGupLWuGk', 'UaywgAqcLxI', 'yhk5u-jl8Us', '9Kt5yrs5uHY', 'aPuPCyD8v_Q', 'sxLOzY5KoC0', '8f4VpYzOCfM', 'ng40tePHABM', 'zvFD5KBAb0Q', '_qHqox5GbeM', '6Jq4cWCyEqY', 'EdqRIRwLtxg', 'DMiV0FeIVUM', 'lSrLb_rERdI', 'DOWDNBu9DkU', 'jbCVdnkaggI', 'ESD8csG4e9c', 'bEKmOVP-SOI', 'NhjZSixg1-M', 'dCzb5G7vh-0', 'moIuur9GUws', 'cu4LPfImpPw', 'HO-31CVnLes', '4lsvWiOb6oo', 'yFfsM_6eYaE', 'j1VVY2sEdC0', 'J1LZbDK4m7M', 'rb6l2hX9z8s', 'ujHUMG0Uovs', 'vWpo6jASKMg', 'HV0bpOotUVQ', 'GZTxqOdcols', 'rskeJFfrASM', '9S2Y7WG8FxY', 'Ru78tYO_vJA', '1PtwZtZ5nt8', 'FaCMpRnwSE0', 'j6b8tUKUQBk', 'H1kLQ7yfY0I', 'S9EnUSSU7HI']
# 50

# %% [markdown]
# # Gathering info on videos in past 72 hours

# %%
import datetime
start_date = datetime.datetime.now(datetime.timezone.utc) - datetime.timedelta(days=3)
start_date = start_date.isoformat()

#this ensures our search is limited to past 72 hours

# %%
request = youtube.search().list(
        part="snippet",
        maxResults=50,
        regionCode="US",
        relevanceLanguage="en",
        safeSearch="moderate",
        type="video",
        publishedAfter=start_date
    ) #request for a service

search_result = request.execute() #execute the request

# %%
print(search_result)
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': '6WwR8l89Vtg5tpED3NXsmU3P3Ps', 'nextPageToken': 'CDIQAA', 'regionCode': 'US', 'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#searchResult', 'etag': 'EBoyOWP-0GhxVlyStRxK-90NSQs', 'id': {'kind': 'youtube#video', 'videoId': 'KA2O08-NhyU'}, 'snippet': {'publishedAt': '2023-03-17T15:00:14Z', 'channelId': 'UC8efBuMd2Tsolb5uTfpex3A', 'title': 'Is J.K. Rowling Transphobic? #Shorts', 'description': 'Watch the Full Episode Here https://youtu.be/ZNcI1vA3JZ4 Listen to the Show on all Podcast Apps "Club Random with Bill Maher" ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KA2O08-NhyU/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/KA2O08-NhyU/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/KA2O08-NhyU/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Club Random Podcast', 'liveBroadcastContent': 'none', 'publishTime': '2023-03-17T15:00:14Z'}}, {'kind': 'youtube#searchResult', 'etag': 'DxY-DdanU0wf6x5ONdNs-oG8bUU', 'id': {'kind': 'youtube#video', 'videoId': 'FellIr6n5oM'}, 'snippet': {'publishedAt': '2023-03-17T15:00:11Z', 'channelId': 'UC4gCTadwb3MiPn_fsZvGAvQ', 'title': 'EU NEM LEMBRO - Henry Freitas (Clipe Oficial)', 'description': 'Ouça agora na sua plataforma digital favorita: https://onerpm.link/verao1000 Se inscreva no canal: ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FellIr6n5oM/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/FellIr6n5oM/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/FellIr6n5oM/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Henry Freitas', 'liveBroadcastContent': 'none', 'publishTime': '2023-03-17T15:00:11Z'}}, {'kind': 'youtube#searchResult', 'etag': 'Pi8eg1_ynjxbsMSoIcLuz5LMCVk', 'id': {'kind': 'youtube#video', 'videoId': 'xKpDux4BKhc'}, 'snippet': {'publishedAt': '2023-03-17T13:28:28Z', 'channelId': 'UCvrhwpnp2DHYQ1CbXby9ypQ', 'title': 'Barathi Kannamma Season 2 | 17th March 2023 - Promo', 'description': 'பாரதி கண்ணம்மா Season 2 - திங்கள் முதல் வெள்ளி வரை இரவு 9 மணிக்கு நம்ம ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xKpDux4BKhc/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/xKpDux4BKhc/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/xKpDux4BKhc/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Vijay Television', 'liveBroadcastContent': 'none', 'publishTime': '2023-03-17T13:28:28Z'}}, {'kind': 'youtube#searchResult', 'etag': 'pRP4uyuCYd7aY_I7MDlZrxJ4BwI', 'id': {'kind': 'youtube#video', 'videoId': 'gGx2u1jofEY'}, 'snippet': {'publishedAt': '2023-03-17T20:36:27Z', 'channelId': 'UCahpxixMCwoANAftn6IxkTg', 'title': 'مسيرة صينية في حرب أوكرانيا تثير دهشة الخبراء.. لماذا؟', 'description': 'دخول المسيرات الصينية التجارية على خط القتال في #أوكرانيا يثير الجدل.. والشركة المصنعة تدين استخدامها عسكريا #العربية ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gGx2u1jofEY/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/gGx2u1jofEY/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/gGx2u1jofEY/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'AlArabiya العربية', 'liveBroadcastContent': 'none', 'publishTime': '2023-03-17T20:36:27Z'}}, {'kind': 'youtube#searchResult', 'etag': 'K_eX4ZRHOU8vpWCWE-5Nl3OKNIA', 'id': {'kind': 'youtube#video', 'videoId': 'Zo1T_gGIDBQ'}, 'snippet': {'publishedAt': '2023-03-17T14:00:31Z', 'channelId': 'UCEIi7zFR_wE23jFncVtd6-A', 'title': '[MIX &amp; MAX] &#39;Thunder&#39; covered by THE BOYZ Q &amp; SUNWOO (큐 &amp; 선우) (4K)', 'description': "[MIX & MAX] Imagine Dragons 'Thunder' covered by THE BOYZ Q & SUNWOO [믹스앤맥스] Imagine Dragons 'Thunder' covered ...", 'thumbnails': {'default': {'url' ...

# %%
print(search_result["items"][0])
# Out:
# {'kind': 'youtube#searchResult', 'etag': 'EBoyOWP-0GhxVlyStRxK-90NSQs', 'id': {'kind': 'youtube#video', 'videoId': 'KA2O08-NhyU'}, 'snippet': {'publishedAt': '2023-03-17T15:00:14Z', 'channelId': 'UC8efBuMd2Tsolb5uTfpex3A', 'title': 'Is J.K. Rowling Transphobic? #Shorts', 'description': 'Watch the Full Episode Here https://youtu.be/ZNcI1vA3JZ4 Listen to the Show on all Podcast Apps "Club Random with Bill Maher" ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KA2O08-NhyU/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/KA2O08-NhyU/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/KA2O08-NhyU/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Club Random Podcast', 'liveBroadcastContent': 'none', 'publishTime': '2023-03-17T15:00:14Z'}}

# %%
video_id = []

# %%
for video in search_result["items"]:
    video_id.append(video["id"]["videoId"])

# %%
if "nextPageToken" in search_result:
    next_page = search_result["nextPageToken"]
    
else:
    next_page = None

# %%
count = 1 #just so we don't overload the API call quota

while next_page and count < 10:
    request = youtube.search().list(
        part="snippet",
        pageToken=next_page,
        maxResults=50,
        regionCode="US",
        relevanceLanguage="en",
        safeSearch="moderate",
        type="video",
        publishedAfter=start_date
    ) #request for a service

    search_result = request.execute() #execute the request
    
    for video in search_result["items"]:
        video_id.append(video["id"]["videoId"])
nOELg', 'JdmjwKuE7co', 'wJju43NQ2jg', '8mPU15gwkKQ', '1gH0qCvtk8I', 'zDXXpEIq2Cs', 'VPUIuxFXrk4', 'E9DcVa7_wUc', '0tEh_t4DbKQ', 'eU6lWz-Tzu8', 'VjTYLgcg_Po', '_GuTvr_aV7w', 'lwOdgEVzTwU', 'fcgMPcPVCSY', 'Oo09lwbtDXU', 'p2hOOOrOkd8', 'wqtuAP8qsck', 'xbP1HVEmhCk', 'ItiqYA3bN54', 'jgg7RmyUHv0', 'IiZBflXaE5s', 'gIg_clePtPg', 'PAXBvB7us3A', 'at_AjThaH84', 'fluqEvEGSAk', 'T8A6Ou4BxEA', 'bNMa9zpq1tM', 'MK8_HVBRLas', 'BgphI74xEkc', 'cyTvJXOBRBc', 'lptvQvSJvSU', 'qqxS7qmVq1k', '87mxVJild5A', 'w5sycdkrR2U', 'OAWQhPx1HcI', 'x5ReUrYrMpw', 'dT6taoucBX4', 'XX2dvEvqCxA', 'mmVfl2LjBaw', 'h8_fLZZOPBQ', 'ESaSKHQKp64', 'EJk1jEguwBw', 'DYRt2LMQ3v4', 'x6me2eGZYFM', 'UX835wSX ...

# %%
#to get more info on each video, we make a request of each videoId
current_videoId = video_id[0]

request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id=current_videoId
    )

video_info = request.execute()

# %%
print(video_info)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': 'G7UabvTTn3CaAJpk6XkEC0qNrF8', 'items': [{'kind': 'youtube#video', 'etag': 'UWOio_VjsiXdhtKBQk23tpRuHpM', 'id': '3Z0HLTENLXU', 'snippet': {'publishedAt': '2023-03-17T16:50:56Z', 'channelId': 'UCqq5n-Oe-r1EEHI3yvhVJcA', 'title': 'بمناسبة ال28 مليون ذهبت لأجمل مكان في العالم ❤️', 'description': 'شاركوووووووووووا وبإذن الله الفوز, البوست نزل في الحساب 👇👇\n👇👇👇👇13 سيارة بقيمة 500ألف ريال, بقى فقط 10 سيارات او قسمتها 👇👇👇👇\nhttps://splay.gg/Aboflah_signup\nhttps://splay.gg/Aboflah_signup\n\n\nإنستقرام:👇\nhttps://www.instagram.com/AboFlah\nتويتر:👇\nhttps://twitter.com/AboFlah_1\n\n✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔\n\n\nشكراً لك إذا ابتسمت بأي مقطع من مقاطعي❤\n\nسبحان الله و بحمدهـ سبحان الله العظيم ♥\n(لا إله إلا الله سبحانك إني كنت من ظالمين)', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3Z0HLTENLXU/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/3Z0HLTENLXU/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/3Z0HLTENLXU/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/3Z0HLTENLXU/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/3Z0HLTENLXU/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'AboFlah', 'tags': ['فله', 'فله\\GAMES', 'الفلاويه', 'قيمز', 'AboFlah', 'حسن', 'أكبر صانع محتوى قيمنق', 'تحدي', 'تحديات', '28 مليون', 'عمرة', 'مكة', 'جوائز', 'اربح سيارة', 'الحج', 'رمضان', 'فلسطين', 'العراق', 'مصر ام الدنيا', 'السعودية', 'ابوفلة', 'مسلسل', 'الهلال', 'أغاني رمضان', 'مسابقات رمضان', 'Cash Prizes', 'Challenges', 'Saudi', 'Crazy Experiment', 'Mecca', 'الحمدلله', 'زلزال', 'english'], 'categoryId': '24', 'liveBroadcastContent': 'none', 'localized': {'title': 'بمناسبة ال28 مليون ذهبت لأجمل مكان في العالم ❤️', 'description': 'شاركوووووووووووا وبإذن الله الفوز, البوست نزل في الحساب 👇👇\n👇👇👇👇13 سيارة بقيمة 500ألف ريال, بقى فقط 10 سيارات او قسمتها 👇👇👇👇\nhttps://splay.gg/Aboflah_signup\nhttps://splay.gg/Aboflah_signup\n\n\nإنستقرام:👇\nhttps://www.instagram.com/AboFlah\nتويتر:👇\nhttps://twitter.com/AboFlah_1\n\n✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔✔\n\n\nشكراً لك إذا ابتسمت بأي مقطع من مقاطعي❤\n\nسبحان الله و بحمدهـ سبحان الله العظيم ♥\n(لا إله إلا الله سبحانك إني كنت من ظالمين)'}, 'defaultAudioLanguage': 'ar'}, 'contentDetails': {'duration': 'PT14M56S', 'dimension': '2d', 'definition': 'hd', 'caption': 'true', 'licensedContent': True, 'contentRating': {}, 'projection': 'rectangular'}, 'statistics': {'viewCount': '2224039', 'likeCount': '372585', 'favoriteCount': '0', 'commentCount': '18304'}}], 'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
import csv

header = ['id', 'publishedAt', 'channelId', 'title', 'description', 'channelTitle', 'categoryId', 'duration', 'dimension', \
          'definition', 'caption', 'viewCount', 'likeCount', 'commentCount', 'Trending']

#There is no trending tag from the API

with open('yt_dataset.csv', 'w', encoding='utf-8', newline='') as f:
    writer = csv.writer(f)
    
    writer.writerow(header)
    
    #For each videoId, we add its details to the csv file
    
    for current_videoId in video_id:
        
        #Get info of video with matching Id
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=current_videoId
        )

        video_info = request.execute()
    
        vi_items = video_info["items"][0]
        snippet = vi_items["snippet"]
        contentDetails = vi_items["contentDetails"]
        statistics = vi_items["statistics"]

        try:
            data = [current_videoId, snippet["publishedAt"], snippet["channelId"], snippet["title"], snippet["description"], \
                   snippet["channelTitle"], snippet["categoryId"], contentDetails["duration"], contentDetails["dimension"], \
                   contentDetails["definition"], contentDetails["caption"], statistics["viewCount"], statistics["likeCount"], \
                   statistics["commentCount"]]
            
            

            #We need to manually check if a video is trending

            if current_videoId in trending_id:
                data.append(1)
                trending_id.remove(current_videoId)

            else:
                data.append(0)
        
        except:
            data = [-1] * len(header)

        writer.writerow(data)
        
    #Add the rest of the trending videos to the csv
    for current_videoId in trending_id:
        
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=current_videoId
        )

        video_info = request.execute()
    
        vi_items = video_info["items"][0]
        snippet = vi_items["snippet"]
        contentDetails = vi_items["contentDetails"]
        statistics = vi_items["statistics"]

        try:
            data = [current_videoId, snippet["publishedAt"], snippet["channelId"], snippet["title"], snippet["description"], \
                   snippet["channelTitle"], snippet["categoryId"], contentDetails["duration"], contentDetails["dimension"], \
                   contentDetails["definition"], contentDetails["caption"], statistics["viewCount"], statistics["likeCount"], \
                   statistics["commentCount"]]

            #These videos are all trending

            data.append(1)
        
        except:
            data = [-1] * len(header)

        writer.writerow(data)
