# %%
import constants

API_KEY = constants.API_KEY

from googleapiclient.discovery import build

# %%
import datetime

current_datetime = datetime.datetime.now()
print(current_datetime.time())

#We run this before 12am SGT each day
while current_datetime.hour != 0:
    current_datetime = datetime.datetime.now()
    time.sleep(1)
    
dataset_name = 'yt_dataset_{}.csv'.format(str(current_datetime.date()))
print(dataset_name)
# Out:
# 23:57:36.140967
# yt_dataset_2023-03-25.csv

# %%
youtube = build('youtube', 'v3', developerKey=API_KEY) #this is a Service

# %% [markdown]
# # Video Id of Trending videos
# We will create an array trending_id containing the video Ids of trending videos.

# %%
request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        chart="mostPopular",
        regionCode="US",
        maxResults=50
    )

trending = request.execute()
print(trending)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': 'lW9GrAV4HQ0YDP2ciPsKvzvgm7w', 'items': [{'kind': 'youtube#video', 'etag': '-cTUgaEd9bg-NB-9NriHIf1SJec', 'id': 'nOI67IDlNMQ', 'snippet': {'publishedAt': '2023-03-24T03:59:08Z', 'channelId': 'UC3IZKseVpdzPSBaWxBxundA', 'title': "지민 (Jimin) 'Like Crazy' Official MV", 'description': "지민 (Jimin) 'Like Crazy' Official MV\n\n'FACE' Release\n📆 3/24 1PM KST | 0AM ET\n💽 Listen to 'FACE': https://ingrv.es/face\n\nCredits:  \nProduction: OUI PRODUCTION\nDirector: Oui Kim\nProducer: Yeonjin Kim, Hyunsik Bang\n1st AD: Huiwon Song\n2nd AD: Sunyoung Kim, Hyeri Shin\n\nDirector of Photography: EumKo\nB Cam Operator: Hyungyun Kim\nFocus Puller: Youngwoo Lee, Heejung Kim\n2nd AC: Eunil Lee, Hyungjun Ahn\nData Manager: Dongwon Choi\n3rd AC: Donghyun Lee\n\nJimmy Jib Operator: Youngjung Kim\nJimmy Jib Assistant: Hyunin Kim, Hojun Choi, Minsu Kim\n\nGrip: Jaekeun Han, Jumyung Lee, Hyunseok Jo\n\nGaffer: Joonghyuk Jung\nCrew: Hyunsuk Kim, Minhyeok Back, Hwayong Chung, Dongyun Sin, Yusung Han, Youngmin Choi\n\nProduction designer/Art Director: Mu:E\nAssistant Art team: Minjung Kim (Mu:E)\nArt-team Manager: ilho Heo (Mu:E)\nTeam Mu:E: Jooho Jeong, Sangwon Cha, Daeyoung Kim\n\nLED: J SHOW COMPANY\nCrew: Daeyeon Hwang, Jonghyun Ryu, Jaehyeong Nam, Myungsung Kim, Eunsung Go, Jisu Lee, Wonhyeok Kim, Sora Chung\n\nVFX: SECONDFLOOR\nVFX Supervisor / FX Lead: Daeyoung Byun\n2D Composite Lead: Ayoung \xa0Lee\n2D Composite Artist: Youngjun Ko, Chea Young Kim\n\n2D(Compositing, Beauty, Emotion Creative): Moonyoung Go\n\nColorist: Changbeen Yu\nAssist: Soyeon Kim\n\nVoiceover Samples - Shelby Young, Joe Brogie\n\n\nBIGHIT MUSIC. Rights are reserved selectively in the video. Unauthorized reproduction is a violation of applicable laws. Manufactured by BIGHIT MUSIC, Seoul, Korea.\n\n\nConnect with BTS: \nhttps://ibighit.com/bts \nhttp://twitter.com/BTS_bighit\nhttp://twitter.com/BTS_
vXiaaIxPHs', 'ntCZjb_AAWE', 'PDDVzUvmZaA', '3tQNiQHON3E', 'yGXaAWbzl5A', '_y9MpNcAitQ', 'EGe5qvIzjTY', 'u6wOyMUs74I', 'MSSdmVe16mo', 'Uv8Cr-Ku3lo', '-aHn0Hk7OCg', '7DaX5-JWbrM', 'TLT_MqzRHfY', 'FbU36ZcRyVk', 'IPqG1qmTNW4', 'jQgd9Ar_hhE', 'JGzkeRHG5Zw', 'a4YoRazp2Uo', 'z4gl9rFAOZI']
# 50

# %% [markdown]
# # Gathering info on videos in past 72 hours

# %%
#This is in UTC

start_date = datetime.datetime.now(datetime.timezone.utc) - datetime.timedelta(days=3)
start_date = start_date.isoformat()

#This ensures our search is limited to past 72 hours

# %%
request = youtube.search().list(
        part="snippet",
        maxResults=50,
        regionCode="US",
        relevanceLanguage="en",
        safeSearch="moderate",
        type="video",
        publishedAfter=start_date
    ) #request for a service

search_result = request.execute() #execute the request

# %%
print(search_result)
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': 'sNSFo6kCV3ld0-Y4Me8S76ubn9w', 'nextPageToken': 'CDIQAA', 'regionCode': 'US', 'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#searchResult', 'etag': 'yT1aQdkSnXxV52W3nEd8UeOVfmM', 'id': {'kind': 'youtube#video', 'videoId': 'dWNIKJdL6lU'}, 'snippet': {'publishedAt': '2023-03-24T07:22:27Z', 'channelId': 'UCrPseYLGpNygVi34QpGNqpA', 'title': 'I&#39;m The Best Rock Paper Scissors Player in the World', 'description': 'follow me on twitter ▻ https://www.twitter.com/ludwigahgren follow me on tiktok ▻ https://www.tiktok.com/@ludwig follow me on ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dWNIKJdL6lU/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/dWNIKJdL6lU/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/dWNIKJdL6lU/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Ludwig', 'liveBroadcastContent': 'none', 'publishTime': '2023-03-24T07:22:27Z'}}, {'kind': 'youtube#searchResult', 'etag': '3xU0FcvZEAkIv4g64N_QWbscgpM', 'id': {'kind': 'youtube#video', 'videoId': 'KHBCyYgEsWA'}, 'snippet': {'publishedAt': '2023-03-22T04:25:21Z', 'channelId': 'UCWJ2lWNubArHWmf3FIHbfcQ', 'title': 'CELTICS at KINGS | FULL GAME HIGHLIGHTS | March 21, 2023', 'description': 'Never miss a moment with the latest news, trending stories and highlights to bring you closer to your favorite players and teams.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KHBCyYgEsWA/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/KHBCyYgEsWA/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/KHBCyYgEsWA/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'NBA', 'liveBroadcastContent': 'none', 'publishTime': '2023-03-22T04:25:21Z'}}, {'kind': 'youtube#searchResult', 'etag': '8R1_F8KuH1mcrvVzuY6U46ZzTr4', 'id': {'kind': 'youtube#video', 'videoId': 'Eeb4aZObp-0'}, 'snippet': {'publishedAt': '2023-03-23T15:59:37Z', 'channelId': 'UCjgpFI5dU-D1-kh9H1muoxQ', 'title': 'We Built a BULLETPROOF John Wick Suit in Real Life!', 'description': 'Go to my sponsor https://aura.com/hacksmith to get a 14 day free trial and see if your personal information has been leaked online ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Eeb4aZObp-0/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/Eeb4aZObp-0/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/Eeb4aZObp-0/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Hacksmith Industries', 'liveBroadcastContent': 'none', 'publishTime': '2023-03-23T15:59:37Z'}}, {'kind': 'youtube#searchResult', 'etag': 's3PzPSlvu7A_dnY4JW8xEObeTww', 'id': {'kind': 'youtube#video', 'videoId': 'fQL16H9HRzg'}, 'snippet': {'publishedAt': '2023-03-23T17:20:17Z', 'channelId': 'UCK7tptUDHh-RYDsdxO1-5QQ', 'title': 'What’s in an Oreo? A Food Scientist Explains | WSJ', 'description': 'Oreos are one of the most well-known cookies in the world, with around 40 billion produced each year. But consumers might not ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fQL16H9HRzg/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/fQL16H9HRzg/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/fQL16H9HRzg/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Wall Street Journal', 'liveBroadcastContent': 'none', 'publishTime': '2023-03-23T17:20:17Z'}}, {'kind': 'youtube#searchResult', 'etag': 'GFaR7BoIpEA919HxyXbr3PVU9XY', 'id': {'kind': 'youtube#video', 'videoId': '8ElMnhldYBI'}, 'snippet': {'publishedAt': '2023-03-24T08:00:03Z', 'channelId': 'UCCXoCcu9Rp7NPbTzIvogpZg', 'title': 'The Hunter Biden story gets ‘wilder’: Miranda Devine', 'description': 'New York Post columnist Miranda Devine discusses the latest in the Hunter Bide ...

# %%
print(search_result["items"][0])
# Out:
# {'kind': 'youtube#searchResult', 'etag': 'yT1aQdkSnXxV52W3nEd8UeOVfmM', 'id': {'kind': 'youtube#video', 'videoId': 'dWNIKJdL6lU'}, 'snippet': {'publishedAt': '2023-03-24T07:22:27Z', 'channelId': 'UCrPseYLGpNygVi34QpGNqpA', 'title': 'I&#39;m The Best Rock Paper Scissors Player in the World', 'description': 'follow me on twitter ▻ https://www.twitter.com/ludwigahgren follow me on tiktok ▻ https://www.tiktok.com/@ludwig follow me on ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dWNIKJdL6lU/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/dWNIKJdL6lU/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/dWNIKJdL6lU/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Ludwig', 'liveBroadcastContent': 'none', 'publishTime': '2023-03-24T07:22:27Z'}}

# %%
video_id = []

# %%
for video in search_result["items"]:
    video_id.append(video["id"]["videoId"])

# %%
if "nextPageToken" in search_result:
    next_page = search_result["nextPageToken"]
    
else:
    next_page = None

# %%
count = 1 #just so we don't overload the API call quota

while next_page and count < 10:
    request = youtube.search().list(
        part="snippet",
        pageToken=next_page,
        maxResults=50,
        regionCode="US",
        relevanceLanguage="en",
        safeSearch="moderate",
        type="video",
        publishedAfter=start_date
    ) #request for a service

    search_result = request.execute() #execute the request
    
    for video in search_result["items"]:
        video_id.append(video["id"]["videoId"])
        
    if "nextPageToken" in search_result:
        next_page = search_result["nextPageToken"]
    
    else:
        next_page = None
    
    count += 1

# %%
video_id = list(set(video_id))
print(video_id, len(video_id))
# Out:
# ['5lpppPsc2n4', 'XvMEd4w0ySA', 'iPd0Ng-dJlo', 'f91EuGNO2bU', 'W2e8D58wu5I', 'zNpFCAUGjPA', 'BTDntSmoB6k', 'z6GRAUL78yc', 'iKBCVZqqooY', 'uqfQqFQtZkI', 'MM-F4voDaYU', 'jwcPFlDAruk', '0TmR8gNcYG4', 'eMM55VyqQiI', 'BX0Odg_OHZg', '3wd2NmlBxWo', 'xai64TcZZ7w', 'bzlGay8yY9Q', 'D1dKUNYdPa

# Out:
# {'kind': 'youtube#videoListResponse', 'etag': 'u4IsSATCa05kmhyd2HFiaVGaAHM', 'items': [{'kind': 'youtube#video', 'etag': 'Dbe8NE4B_s_4bmef2nmKupIgoRI', 'id': '5lpppPsc2n4', 'snippet': {'publishedAt': '2023-03-24T04:00:03Z', 'channelId': 'UCE6l2NHQkpgF_P96isfOu4Q', 'title': 'Like Crazy', 'description': "Provided to YouTube by 'BIGHIT MUSIC'\n\nLike Crazy · 지민 (Jimin)\n\nFACE\n\nReleased on: 2023-03-24\n\nAuto-generated by YouTube.", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5lpppPsc2n4/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/5lpppPsc2n4/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/5lpppPsc2n4/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/5lpppPsc2n4/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/5lpppPsc2n4/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'Jimin - Topic', 'tags': ['지민 (Jimin)', 'Jimin', 'FACE', 'Like Crazy'], 'categoryId': '10', 'liveBroadcastContent': 'none', 'localized': {'title': 'Like Crazy', 'description': "Provided to YouTube by 'BIGHIT MUSIC'\n\nLike Crazy · 지민 (Jimin)\n\nFACE\n\nReleased on: 2023-03-24\n\nAuto-generated by YouTube."}}, 'contentDetails': {'duration': 'PT3M33S', 'dimension': '2d', 'definition': 'hd', 'caption': 'false', 'licensedContent': True, 'contentRating': {}, 'projection': 'rectangular'}, 'statistics': {'viewCount': '252368', 'likeCount': '49037', 'favoriteCount': '0', 'commentCount': '0'}}], 'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
import csv
    
header = ['id', 'publishedAt', 'channelId', 'title', 'description', 'channelTitle', 'categoryId', 'duration', 'dimension', \
          'definition', 'caption', 'viewCount', 'likeCount', 'commentCount', 'Trending']

#There is no trending tag from the API

with open(dataset_name, 'w', encoding='utf-8', newline='') as f:
    writer = csv.writer(f)
    
    writer.writerow(header)
    
    #For each videoId, we add its details to the csv file
    
    for current_videoId in video_id:
        
        #Get info of video with matching Id
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=current_videoId
        )

        video_info = request.execute()
    
        vi_items = video_info["items"][0]
        snippet = vi_items["snippet"]
        contentDetails = vi_items["contentDetails"]
        statistics = vi_items["statistics"]


        if "viewCount" not in statistics:
            statistics["viewCount"] = "None"

        if "likeCount" not in statistics:
            statistics["likeCount"] = "None"
            
        if "commentCount" not in statistics:
            statistics["commentCount"] = "None"
            

        data = [current_videoId, snippet["publishedAt"], snippet["channelId"], snippet["title"], snippet["description"], \
               snippet["channelTitle"], snippet["categoryId"], contentDetails["duration"], contentDetails["dimension"], \
               contentDetails["definition"], contentDetails["caption"], statistics["viewCount"], statistics["likeCount"], \
               statistics["commentCount"]]


        #We need to manually check if a video is trending

        if current_videoId in trending_id:
            data.append(1)
            trending_id.remove(current_videoId)

        else:
            data.append(0)

        writer.writerow(data)
        
    #Add the rest of the trending videos to the csv
    for current_videoId in trending_id:
        
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=current_videoId
        )

        video_info = request.execute()
    
        vi_items = video_info["items"][0]
        snippet = vi_items["snippet"]
        contentDetails = vi_items["contentDetails"]
        statistics = vi_items["statistics"]


        if "viewCount" not in statistics:
            statistics["viewCount"] = "None"

        if "likeCount" not in statistics:
            statistics["likeCount"] = "None"
            
        if "commentCount" not in statistics:
            statistics["commentCount"] = "None"

        data = [current_videoId, snippet["publishedAt"], snippet["channelId"], snippet["title"], snippet["description"], \
               snippet["channelTitle"], snippet["categoryId"], contentDetails["duration"], contentDetails["dimension"], \
               contentDetails["definition"], contentDetails["caption"], statistics["viewCount"], statistics["likeCount"], \
               statistics["commentCount"]]
        
        data.append(1)

        writer.writerow(data)
